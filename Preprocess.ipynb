# %%
import pandas as pd
import numpy as np
import mne
import os
from mne.time_frequency import psd_array_welch
from scipy.signal import welch

EEG_DATA_PATH = "Dataset/eremus_dataset/pruned/train"
# Load the CSV file into a Pandas DataFrame
df = pd.read_csv('/Users/harsh_dadwal/Harsh/coding/ml/music_eeg/Emotions_Train.csv')

# %%
def compute_features(eeg_data, sampling_rate=128):
    features = {}
    
    # Compute Power Spectral Density (PSD) using Welch's method
    psds, freqs = psd_array_welch(eeg_data, sfreq=sampling_rate, fmin=0.5, fmax=40, n_fft=2048)

    # Extract PSD for different frequency bands (Alpha, Beta, Delta, Theta)
    features['alpha_power'] = np.mean(psds[:, (freqs >= 8) & (freqs <= 12)], axis=1)  # Alpha (8-12 Hz)
    features['beta_power'] = np.mean(psds[:, (freqs >= 12) & (freqs <= 30)], axis=1)  # Beta (12-30 Hz)
    features['delta_power'] = np.mean(psds[:, (freqs >= 0.5) & (freqs <= 4)], axis=1)  # Delta (0.5-4 Hz)
    features['theta_power'] = np.mean(psds[:, (freqs >= 4) & (freqs <= 8)], axis=1)    # Theta (4-8 Hz)
    
    # Variance of the EEG data
    features['variance'] = np.var(eeg_data, axis=1)

    # Mean of the EEG data
    features['mean'] = np.mean(eeg_data, axis=1)

    return features

# %%
# Custom Exception for Residual NaNs
class ResidualNan(Exception):
    pass

def interpolate_nans(data):
    """Interpolate NaN values in the EEG data."""
    # Get the indices of NaNs
    nan_indices = np.where(np.isnan(data))
    nan_indices = np.vstack(nan_indices).transpose()

    # Interpolate NaNs for each channel
    for channel, timepoint in nan_indices:
        if timepoint == 0 or timepoint == data.shape[1] - 1:
            # If NaN is at the start or end, we can't interpolate, set to 0
            data[channel, timepoint] = 0
        else:
            # Interpolate using neighboring values
            before = data[channel, timepoint - 1]
            after = data[channel, timepoint + 1]
            data[channel, timepoint] = (before + after) / 2

    # Check if any NaNs remain
    nan_indices = np.where(np.isnan(data))
    if nan_indices[0].size > 0:
        raise ResidualNan("Data still contains NaNs after interpolation")

    return data

def load_eeg_data(trial_id):
    """Load and preprocess EEG data, handling NaNs."""
    # Path to the EEG .fif file
    eeg_file_path = f'Dataset/eremus_dataset/pruned/train/{trial_id}_eeg.fif'
    
    # Load the EEG data from the .fif file
    raw = mne.io.read_raw_fif(eeg_file_path, preload=True)
    
    # Extract the data and the sampling frequency
    eeg_data = raw.get_data()
    
    # Handle NaN values by interpolation
    try:
        eeg_data = interpolate_nans(eeg_data)
    except ResidualNan as e:
        print(f"Residual NaNs in {trial_id}_eeg.fif")
        return None, None  # Skip this trial if NaNs cannot be handled

    return eeg_data, raw.info['sfreq']

# %%
for index, row in df.iterrows():
    trial_id = row['id']  # Assuming 'id' corresponds to the trial_id in the .fif filename
    
    # Load the corresponding EEG data
    eeg_data, sfreq = load_eeg_data(trial_id)
    
    # Compute the features
    features = compute_features(eeg_data, sampling_rate=sfreq)
    
    # Add the features to the DataFrame
    df.loc[index, 'alpha_power'] = np.mean(features['alpha_power'])
    df.loc[index, 'beta_power'] = np.mean(features['beta_power'])
    df.loc[index, 'delta_power'] = np.mean(features['delta_power'])
    df.loc[index, 'theta_power'] = np.mean(features['theta_power'])
    df.loc[index, 'variance'] = np.mean(features['variance'])
    df.loc[index, 'mean'] = np.mean(features['mean'])
# Out:
# Opening raw data file Dataset/eremus_dataset/pruned/train/3784258358_eeg.fif...
#     Range : 9361 ... 19600 =     73.133 ...   153.125 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2395445698_eeg.fif...
#     Range : 20939 ... 31178 =    163.586 ...   243.578 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3049220457_eeg.fif...
#     Range : 32286 ... 42525 =    252.234 ...   332.227 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2667905835_eeg.fif...
#     Range : 44256 ... 54495 =    345.750 ...   425.742 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1281311748_eeg.fif...
#     Range : 56100 ... 66339 =    438.281 ...   518.273 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2608559859_eeg.fif...
#     Range : 8958 ... 19756 =     69.984 ...   154.344 secs
# Ready.
# Reading 0 ... 10798  =      0.000 ...    84.359 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2596145110_eeg.fif...
#     Range : 24142 ... 35123 =    188.609 ...   274.398 secs
# Ready.
# Reading 0 ... 10981  =      0.000 ...    85.789 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8309820898_eeg.fif...
#     Range : 38490 ... 50006 =    300.703 ...   390.672 secs
# Ready.
# Reading 0 ... 11516  =      0.000 ...    89.969 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7497445780_eeg.fif...
#     Range : 53973 ... 65252 =    421.664 ...   509.781 secs
# Ready.
# Reading 0 ... 11279  =      0.000 ...    88.117 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6438333572_eeg.fif...
#     Range : 68621 ... 80349 =    536.102 ...   627.727 secs
# Ready.
# Reading 0 ... 11728  =      0.000 ...    91.625 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8557039094_eeg.fif...
#     Range : 7589 ... 17828 =     59.289 ...   139.281 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/9029879903_eeg.fif...
#     Range : 25777 ... 36016 =    201.383 ...   281.375 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3361324029_eeg.fif...
#     Range : 37147 ... 47386 =    290.211 ...   370.203 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7418585150_eeg.fif...
#     Range : 48791 ... 59030 =    381.180 ...   461.172 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6243009174_eeg.fif...
#     Range : 61575 ... 71814 =    481.055 ...   561.047 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7391036738_eeg.fif...
#     Range : 6915 ... 17991 =     54.023 ...   140.555 secs
# Ready.
# Reading 0 ... 11076  =      0.000 ...    86.531 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5280159555_eeg.fif...
#     Range : 22270 ... 33791 =    173.984 ...   263.992 secs
# Ready.
# Reading 0 ... 11521  =      0.000 ...    90.008 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1553935701_eeg.fif...
#     Range : 36788 ... 48451 =    287.406 ...   378.523 secs
# Ready.
# Reading 0 ... 11663  =      0.000 ...    91.117 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8026221597_eeg.fif...
#     Range : 52822 ... 64517 =    412.672 ...   504.039 secs
# Ready.
# Reading 0 ... 11695  =      0.000 ...    91.367 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2956923308_eeg.fif...
#     Range : 70315 ... 81977 =    549.336 ...   640.445 secs
# Ready.
# Reading 0 ... 11662  =      0.000 ...    91.109 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3314920082_eeg.fif...
#     Range : 8190 ... 18223 =     63.984 ...   142.367 secs
# Ready.
# Reading 0 ... 10033  =      0.000 ...    78.383 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2951988720_eeg.fif...
#     Range : 18357 ... 29972 =    143.414 ...   234.156 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6021862951_eeg.fif...
#     Range : 30069 ... 41684 =    234.914 ...   325.656 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1436191677_eeg.fif...
#     Range : 41784 ... 53400 =    326.438 ...   417.188 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2302906161_eeg.fif...
#     Range : 53542 ... 65155 =    418.297 ...   509.023 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8084230089_eeg.fif...
#     Range : 9467 ... 21084 =     73.961 ...   164.719 secs
# Ready.
# Reading 0 ... 11617  =      0.000 ...    90.758 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2059040442_eeg.fif...
#     Range : 27093 ... 38707 =    211.664 ...   302.398 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5161760361_eeg.fif...
#     Range : 43003 ... 54617 =    335.961 ...   426.695 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2063266754_eeg.fif...
#     Range : 60545 ... 72159 =    473.008 ...   563.742 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3130546511_eeg.fif...
#     Range : 6708 ... 18324 =     52.406 ...   143.156 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5417594918_eeg.fif...
#     Range : 18442 ... 30052 =    144.078 ...   234.781 secs
# Ready.
# Reading 0 ... 11610  =      0.000 ...    90.703 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4506496120_eeg.fif...
#     Range : 30258 ... 41877 =    236.391 ...   327.164 secs
# Ready.
# Reading 0 ... 11619  =      0.000 ...    90.773 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3508699688_eeg.fif...
#     Range : 42157 ... 53771 =    329.352 ...   420.086 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4544608223_eeg.fif...
#     Range : 54140 ... 65754 =    422.969 ...   513.703 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1135903657_eeg.fif...
#     Range : 7040 ... 17726 =     55.000 ...   138.484 secs
# Ready.
# Reading 0 ... 10686  =      0.000 ...    83.484 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8861397241_eeg.fif...
#     Range : 20072 ... 31688 =    156.812 ...   247.562 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/9865031713_eeg.fif...
#     Range : 36620 ... 48234 =    286.094 ...   376.828 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2400639464_eeg.fif...
#     Range : 52367 ... 63980 =    409.117 ...   499.844 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4902264143_eeg.fif...
#     Range : 70636 ... 82249 =    551.844 ...   642.570 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5713478846_eeg.fif...
#     Range : 15685 ... 27357 =    122.539 ...   213.727 secs
# Ready.
# Reading 0 ... 11672  =      0.000 ...    91.188 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/9195527806_eeg.fif...
#     Range : 28239 ... 39492 =    220.617 ...   308.531 secs
# Ready.
# Reading 0 ... 11253  =      0.000 ...    87.914 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6705473117_eeg.fif...
#     Range : 45238 ... 56460 =    353.422 ...   441.094 secs
# Ready.
# Reading 0 ... 11222  =      0.000 ...    87.672 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/9187213890_eeg.fif...
#     Range : 57025 ... 68586 =    445.508 ...   535.828 secs
# Ready.
# Reading 0 ... 11561  =      0.000 ...    90.320 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7395858685_eeg.fif...
#     Range : 68983 ... 81488 =    538.930 ...   636.625 secs
# Ready.
# Reading 0 ... 12505  =      0.000 ...    97.695 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2848873660_eeg.fif...
#     Range : 8101 ... 19195 =     63.289 ...   149.961 secs
# Ready.
# Reading 0 ... 11094  =      0.000 ...    86.672 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6194767697_eeg.fif...
#     Range : 27150 ... 38767 =    212.109 ...   302.867 secs
# Ready.
# Reading 0 ... 11617  =      0.000 ...    90.758 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5898249712_eeg.fif...
#     Range : 44931 ... 56547 =    351.023 ...   441.773 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3380252349_eeg.fif...
#     Range : 88092 ... 99708 =    688.219 ...   778.969 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/9194938561_eeg.fif...
#     Range : 13304 ... 24917 =    103.938 ...   194.664 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3806403451_eeg.fif...
#     Range : 25025 ... 36640 =    195.508 ...   286.250 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5814295082_eeg.fif...
#     Range : 36734 ... 48348 =    286.984 ...   377.719 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4945916145_eeg.fif...
#     Range : 48454 ... 60070 =    378.547 ...   469.297 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/9278136281_eeg.fif...
#     Range : 97605 ... 109219 =    762.539 ...   853.273 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8504350846_eeg.fif...
#     Range : 6320 ... 17933 =     49.375 ...   140.102 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1661499903_eeg.fif...
#     Range : 20673 ... 32285 =    161.508 ...   252.227 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4455223918_eeg.fif...
#     Range : 35246 ... 46860 =    275.359 ...   366.094 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7272595194_eeg.fif...
#     Range : 53498 ... 65110 =    417.953 ...   508.672 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5997913581_eeg.fif...
#     Range : 69735 ... 81353 =    544.805 ...   635.570 secs
# Ready.
# Reading 0 ... 11618  =      0.000 ...    90.766 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4434637720_eeg.fif...
#     Range : 17418 ... 29103 =    136.078 ...   227.367 secs
# Ready.
# Reading 0 ... 11685  =      0.000 ...    91.289 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1143753231_eeg.fif...
#     Range : 29597 ... 41216 =    231.227 ...   322.000 secs
# Ready.
# Reading 0 ... 11619  =      0.000 ...    90.773 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7841323991_eeg.fif...
#     Range : 41583 ... 56480 =    324.867 ...   441.250 secs
# Ready.
# Reading 0 ... 14897  =      0.000 ...   116.383 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1518675867_eeg.fif...
#     Range : 56960 ... 68951 =    445.000 ...   538.680 secs
# Ready.
# Reading 0 ... 11991  =      0.000 ...    93.680 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7653858464_eeg.fif...
#     Range : 69366 ... 81268 =    541.922 ...   634.906 secs
# Ready.
# Reading 0 ... 11902  =      0.000 ...    92.984 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8761538642_eeg.fif...
#     Range : 24888 ... 36501 =    194.438 ...   285.164 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5390770597_eeg.fif...
#     Range : 41447 ... 53065 =    323.805 ...   414.570 secs
# Ready.
# Reading 0 ... 11618  =      0.000 ...    90.766 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2978076428_eeg.fif...
#     Range : 57852 ... 69467 =    451.969 ...   542.711 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5485211163_eeg.fif...
#     Range : 8945 ... 20568 =     69.883 ...   160.688 secs
# Ready.
# Reading 0 ... 11623  =      0.000 ...    90.805 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5720039635_eeg.fif...
#     Range : 20690 ... 32307 =    161.641 ...   252.398 secs
# Ready.
# Reading 0 ... 11617  =      0.000 ...    90.758 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8408869665_eeg.fif...
#     Range : 32429 ... 44042 =    253.352 ...   344.078 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6727568737_eeg.fif...
#     Range : 44125 ... 55738 =    344.727 ...   435.453 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5632497865_eeg.fif...
#     Range : 55831 ... 67443 =    436.180 ...   526.898 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8260045543_eeg.fif...
#     Range : 7461 ... 19075 =     58.289 ...   149.023 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1188018273_eeg.fif...
#     Range : 21558 ... 33174 =    168.422 ...   259.172 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3114008345_eeg.fif...
#     Range : 50317 ... 61932 =    393.102 ...   483.844 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5688213647_eeg.fif...
#     Range : 64061 ... 75676 =    500.477 ...   591.219 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4497446683_eeg.fif...
#     Range : 9213 ... 20828 =     71.977 ...   162.719 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7156480045_eeg.fif...
#     Range : 20908 ... 32520 =    163.344 ...   254.062 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3395991636_eeg.fif...
#     Range : 32625 ... 44239 =    254.883 ...   345.617 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7743275347_eeg.fif...
#     Range : 44319 ... 55938 =    346.242 ...   437.016 secs
# Ready.
# Reading 0 ... 11619  =      0.000 ...    90.773 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1655099904_eeg.fif...
#     Range : 56037 ... 67652 =    437.789 ...   528.531 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2671256194_eeg.fif...
#     Range : 7592 ... 19207 =     59.312 ...   150.055 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8974662405_eeg.fif...
#     Range : 22408 ... 34025 =    175.062 ...   265.820 secs
# Ready.
# Reading 0 ... 11617  =      0.000 ...    90.758 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6783991619_eeg.fif...
#     Range : 50507 ... 62127 =    394.586 ...   485.367 secs
# Ready.
# Reading 0 ... 11620  =      0.000 ...    90.781 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7674400972_eeg.fif...
#     Range : 7512 ... 19127 =     58.688 ...   149.430 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2442807919_eeg.fif...
#     Range : 19296 ... 30910 =    150.750 ...   241.484 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6370584383_eeg.fif...
#     Range : 31003 ... 42614 =    242.211 ...   332.922 secs
# Ready.
# Reading 0 ... 11611  =      0.000 ...    90.711 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1315779175_eeg.fif...
#     Range : 42691 ... 54303 =    333.523 ...   424.242 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1585219913_eeg.fif...
#     Range : 54437 ... 66049 =    425.289 ...   516.008 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7289346890_eeg.fif...
#     Range : 8621 ... 20234 =     67.352 ...   158.078 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5568667703_eeg.fif...
#     Range : 23812 ... 35426 =    186.031 ...   276.766 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4088218377_eeg.fif...
#     Range : 58484 ... 70095 =    456.906 ...   547.617 secs
# Ready.
# Reading 0 ... 11611  =      0.000 ...    90.711 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8995791781_eeg.fif...
#     Range : 15453 ... 27071 =    120.727 ...   211.492 secs
# Ready.
# Reading 0 ... 11618  =      0.000 ...    90.766 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7307194539_eeg.fif...
#     Range : 27177 ... 38789 =    212.320 ...   303.039 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5438162578_eeg.fif...
#     Range : 38872 ... 50490 =    303.688 ...   394.453 secs
# Ready.
# Reading 0 ... 11618  =      0.000 ...    90.766 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5430407454_eeg.fif...
#     Range : 50565 ... 62179 =    395.039 ...   485.773 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4501146986_eeg.fif...
#     Range : 62313 ... 73919 =    486.820 ...   577.492 secs
# Ready.
# Reading 0 ... 11606  =      0.000 ...    90.672 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3152082844_eeg.fif...
#     Range : 9994 ... 21610 =     78.078 ...   168.828 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3994531682_eeg.fif...
#     Range : 24701 ... 36315 =    192.977 ...   283.711 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4361083316_eeg.fif...
#     Range : 39049 ... 50668 =    305.070 ...   395.844 secs
# Ready.
# Reading 0 ... 11619  =      0.000 ...    90.773 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4743062887_eeg.fif...
#     Range : 55156 ... 66775 =    430.906 ...   521.680 secs
# Ready.
# Reading 0 ... 11619  =      0.000 ...    90.773 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3679424236_eeg.fif...
#     Range : 69444 ... 81058 =    542.531 ...   633.266 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2965155855_eeg.fif...
#     Range : 8414 ... 20029 =     65.734 ...   156.477 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5768080515_eeg.fif...
#     Range : 20096 ... 31709 =    157.000 ...   247.727 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4278441823_eeg.fif...
#     Range : 31807 ... 43428 =    248.492 ...   339.281 secs
# Ready.
# Reading 0 ... 11621  =      0.000 ...    90.789 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8446090510_eeg.fif...
#     Range : 43554 ... 55167 =    340.266 ...   430.992 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3727709568_eeg.fif...
#     Range : 55253 ... 66867 =    431.664 ...   522.398 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2505977396_eeg.fif...
#     Range : 9351 ... 20963 =     73.055 ...   163.773 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8760537468_eeg.fif...
#     Range : 41997 ... 53608 =    328.102 ...   418.812 secs
# Ready.
# Reading 0 ... 11611  =      0.000 ...    90.711 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3359788067_eeg.fif...
#     Range : 57002 ... 68618 =    445.328 ...   536.078 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7690688371_eeg.fif...
#     Range : 72561 ... 84178 =    566.883 ...   657.641 secs
# Ready.
# Reading 0 ... 11617  =      0.000 ...    90.758 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2642234932_eeg.fif...
#     Range : 10162 ... 21774 =     79.391 ...   170.109 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5984395806_eeg.fif...
#     Range : 21873 ... 33493 =    170.883 ...   261.664 secs
# Ready.
# Reading 0 ... 11620  =      0.000 ...    90.781 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3244438535_eeg.fif...
#     Range : 35789 ... 47596 =    279.602 ...   371.844 secs
# Ready.
# Reading 0 ... 11807  =      0.000 ...    92.242 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2686839582_eeg.fif...
#     Range : 48291 ... 59980 =    377.273 ...   468.594 secs
# Ready.
# Reading 0 ... 11689  =      0.000 ...    91.320 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5548440787_eeg.fif...
#     Range : 60605 ... 72568 =    473.477 ...   566.938 secs
# Ready.
# Reading 0 ... 11963  =      0.000 ...    93.461 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3603031333_eeg.fif...
#     Range : 9066 ... 20680 =     70.828 ...   161.562 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7194194602_eeg.fif...
#     Range : 26539 ... 38154 =    207.336 ...   298.078 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3530449582_eeg.fif...
#     Range : 42130 ... 53742 =    329.141 ...   419.859 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5877317675_eeg.fif...
#     Range : 62128 ... 73742 =    485.375 ...   576.109 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8588964370_eeg.fif...
#     Range : 80383 ... 92000 =    627.992 ...   718.750 secs
# Ready.
# Reading 0 ... 11617  =      0.000 ...    90.758 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6572251116_eeg.fif...
#     Range : 11197 ... 22810 =     87.477 ...   178.203 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8633315042_eeg.fif...
#     Range : 22880 ... 34494 =    178.750 ...   269.484 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2926730303_eeg.fif...
#     Range : 34624 ... 46240 =    270.500 ...   361.250 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4616757922_eeg.fif...
#     Range : 46326 ... 57939 =    361.922 ...   452.648 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2052607919_eeg.fif...
#     Range : 58039 ... 69655 =    453.430 ...   544.180 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3471264357_eeg.fif...
#     Range : 9027 ... 20641 =     70.523 ...   161.258 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2102668116_eeg.fif...
#     Range : 23365 ... 34978 =    182.539 ...   273.266 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2016546257_eeg.fif...
#     Range : 38672 ... 50288 =    302.125 ...   392.875 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3088725053_eeg.fif...
#     Range : 53126 ... 64740 =    415.047 ...   505.781 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4353988101_eeg.fif...
#     Range : 71425 ... 83039 =    558.008 ...   648.742 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7962692464_eeg.fif...
#     Range : 9429 ... 21051 =     73.664 ...   164.461 secs
# Ready.
# Reading 0 ... 11622  =      0.000 ...    90.797 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3495474224_eeg.fif...
#     Range : 21158 ... 32772 =    165.297 ...   256.031 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5661316078_eeg.fif...
#     Range : 32870 ... 44482 =    256.797 ...   347.516 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6808721773_eeg.fif...
#     Range : 44565 ... 56178 =    348.164 ...   438.891 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3096895971_eeg.fif...
#     Range : 56312 ... 67930 =    439.938 ...   530.703 secs
# Ready.
# Reading 0 ... 11618  =      0.000 ...    90.766 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1555197220_eeg.fif...
#     Range : 9565 ... 21180 =     74.727 ...   165.469 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7933831782_eeg.fif...
#     Range : 25090 ... 36705 =    196.016 ...   286.758 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2644432196_eeg.fif...
#     Range : 40203 ... 51819 =    314.086 ...   404.836 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4675514143_eeg.fif...
#     Range : 58982 ... 70598 =    460.797 ...   551.547 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1939422702_eeg.fif...
#     Range : 76103 ... 87718 =    594.555 ...   685.297 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7614455755_eeg.fif...
#     Range : 11023 ... 22638 =     86.117 ...   176.859 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7659822209_eeg.fif...
#     Range : 22733 ... 34348 =    177.602 ...   268.344 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8921956452_eeg.fif...
#     Range : 34440 ... 46055 =    269.062 ...   359.805 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3218016765_eeg.fif...
#     Range : 46204 ... 57818 =    360.969 ...   451.703 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5028307864_eeg.fif...
#     Range : 57902 ... 69517 =    452.359 ...   543.102 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7245345626_eeg.fif...
#     Range : 16487 ... 24259 =    128.805 ...   189.523 secs
# Ready.
# Reading 0 ... 7772  =      0.000 ...    60.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5625289942_eeg.fif...
#     Range : 63427 ... 75039 =    495.523 ...   586.242 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3322571246_eeg.fif...
#     Range : 81416 ... 93027 =    636.062 ...   726.773 secs
# Ready.
# Reading 0 ... 11611  =      0.000 ...    90.711 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5834815628_eeg.fif...
#     Range : 97813 ... 109424 =    764.164 ...   854.875 secs
# Ready.
# Reading 0 ... 11611  =      0.000 ...    90.711 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/9903556545_eeg.fif...
#     Range : 8463 ... 20079 =     66.117 ...   156.867 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4466858062_eeg.fif...
#     Range : 20179 ... 31798 =    157.648 ...   248.422 secs
# Ready.
# Reading 0 ... 11619  =      0.000 ...    90.773 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1036331628_eeg.fif...
#     Range : 31864 ... 42086 =    248.938 ...   328.797 secs
# Ready.
# Reading 0 ... 10222  =      0.000 ...    79.859 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8039661904_eeg.fif...
#     Range : 42149 ... 53758 =    329.289 ...   419.984 secs
# Ready.
# Reading 0 ... 11609  =      0.000 ...    90.695 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8269497269_eeg.fif...
#     Range : 53829 ... 65446 =    420.539 ...   511.297 secs
# Ready.
# Reading 0 ... 11617  =      0.000 ...    90.758 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5601425099_eeg.fif...
#     Range : 16198 ... 27812 =    126.547 ...   217.281 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/9632679687_eeg.fif...
#     Range : 33455 ... 45069 =    261.367 ...   352.102 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6838666719_eeg.fif...
#     Range : 48925 ... 60536 =    382.227 ...   472.938 secs
# Ready.
# Reading 0 ... 11611  =      0.000 ...    90.711 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3096596590_eeg.fif...
#     Range : 63287 ... 74900 =    494.430 ...   585.156 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4844792828_eeg.fif...
#     Range : 79863 ... 91477 =    623.930 ...   714.664 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3723881509_eeg.fif...
#     Range : 8983 ... 20598 =     70.180 ...   160.922 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4781312231_eeg.fif...
#     Range : 20705 ... 32320 =    161.758 ...   252.500 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3969424776_eeg.fif...
#     Range : 32398 ... 44011 =    253.109 ...   343.836 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5570824274_eeg.fif...
#     Range : 44103 ... 55724 =    344.555 ...   435.344 secs
# Ready.
# Reading 0 ... 11621  =      0.000 ...    90.789 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7242492203_eeg.fif...
#     Range : 55827 ... 67439 =    436.148 ...   526.867 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4816131098_eeg.fif...
#     Range : 8285 ... 19894 =     64.727 ...   155.422 secs
# Ready.
# Reading 0 ... 11609  =      0.000 ...    90.695 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2566335050_eeg.fif...
#     Range : 23962 ... 35581 =    187.203 ...   277.977 secs
# Ready.
# Reading 0 ... 11619  =      0.000 ...    90.773 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3386464197_eeg.fif...
#     Range : 55224 ... 66838 =    431.438 ...   522.172 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8531768944_eeg.fif...
#     Range : 69550 ... 81166 =    543.359 ...   634.109 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3105886107_eeg.fif...
#     Range : 10772 ... 22385 =     84.156 ...   174.883 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8012044164_eeg.fif...
#     Range : 22520 ... 34135 =    175.938 ...   266.680 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3093701702_eeg.fif...
#     Range : 34201 ... 45817 =    267.195 ...   357.945 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3454262054_eeg.fif...
#     Range : 45894 ... 57508 =    358.547 ...   449.281 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7729918684_eeg.fif...
#     Range : 57610 ... 69223 =    450.078 ...   540.805 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6667049702_eeg.fif...
#     Range : 14511 ... 26127 =    113.367 ...   204.117 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7594592186_eeg.fif...
#     Range : 28181 ... 39792 =    220.164 ...   310.875 secs
# Ready.
# Reading 0 ... 11611  =      0.000 ...    90.711 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4104057682_eeg.fif...
#     Range : 42459 ... 54078 =    331.711 ...   422.484 secs
# Ready.
# Reading 0 ... 11619  =      0.000 ...    90.773 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6361287970_eeg.fif...
#     Range : 56398 ... 68012 =    440.609 ...   531.344 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8679265186_eeg.fif...
#     Range : 69917 ... 81531 =    546.227 ...   636.961 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4004617796_eeg.fif...
#     Range : 11345 ... 22958 =     88.633 ...   179.359 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3368028902_eeg.fif...
#     Range : 23090 ... 34705 =    180.391 ...   271.133 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1379215716_eeg.fif...
#     Range : 34816 ... 46431 =    272.000 ...   362.742 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3140286472_eeg.fif...
#     Range : 46536 ... 58148 =    363.562 ...   454.281 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7418038546_eeg.fif...
#     Range : 58659 ... 69889 =    458.273 ...   546.008 secs
# Ready.
# Reading 0 ... 11230  =      0.000 ...    87.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5700100690_eeg.fif...
#     Range : 8972 ... 20587 =     70.094 ...   160.836 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7481350683_eeg.fif...
#     Range : 40335 ... 51950 =    315.117 ...   405.859 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7793268524_eeg.fif...
#     Range : 56775 ... 68388 =    443.555 ...   534.281 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1140388329_eeg.fif...
#     Range : 72263 ... 83877 =    564.555 ...   655.289 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4719909019_eeg.fif...
#     Range : 10997 ... 22609 =     85.914 ...   176.633 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4495132490_eeg.fif...
#     Range : 22712 ... 34324 =    177.438 ...   268.156 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7887564928_eeg.fif...
#     Range : 34427 ... 46038 =    268.961 ...   359.672 secs
# Ready.
# Reading 0 ... 11611  =      0.000 ...    90.711 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4025883015_eeg.fif...
#     Range : 46109 ... 57722 =    360.227 ...   450.953 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8066471705_eeg.fif...
#     Range : 57860 ... 69473 =    452.031 ...   542.758 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4975883943_eeg.fif...
#     Range : 15771 ... 26010 =    123.211 ...   203.203 secs
# Ready.
# Reading 0 ... 10239  =      0.000 ...    79.992 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7278971454_eeg.fif...
#     Range : 33860 ... 45325 =    264.531 ...   354.102 secs
# Ready.
# Reading 0 ... 11465  =      0.000 ...    89.570 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7793853278_eeg.fif...
#     Range : 48209 ... 59818 =    376.633 ...   467.328 secs
# Ready.
# Reading 0 ... 11609  =      0.000 ...    90.695 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7550116739_eeg.fif...
#     Range : 81826 ... 93291 =    639.266 ...   728.836 secs
# Ready.
# Reading 0 ... 11465  =      0.000 ...    89.570 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/2958450681_eeg.fif...
#     Range : 16962 ... 28584 =    132.516 ...   223.312 secs
# Ready.
# Reading 0 ... 11622  =      0.000 ...    90.797 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8131355824_eeg.fif...
#     Range : 28966 ... 40328 =    226.297 ...   315.062 secs
# Ready.
# Reading 0 ... 11362  =      0.000 ...    88.766 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5018959303_eeg.fif...
#     Range : 40419 ... 52033 =    315.773 ...   406.508 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5905614682_eeg.fif...
#     Range : 52112 ... 63728 =    407.125 ...   497.875 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/9044452233_eeg.fif...
#     Range : 63858 ... 75468 =    498.891 ...   589.594 secs
# Ready.
# Reading 0 ... 11610  =      0.000 ...    90.703 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4972329495_eeg.fif...
#     Range : 8084 ... 19702 =     63.156 ...   153.922 secs
# Ready.
# Reading 0 ... 11618  =      0.000 ...    90.766 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7553120384_eeg.fif...
#     Range : 23535 ... 35156 =    183.867 ...   274.656 secs
# Ready.
# Reading 0 ... 11621  =      0.000 ...    90.789 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3909196796_eeg.fif...
#     Range : 40971 ... 52592 =    320.086 ...   410.875 secs
# Ready.
# Reading 0 ... 11621  =      0.000 ...    90.789 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3856029503_eeg.fif...
#     Range : 13466 ... 25084 =    105.203 ...   195.969 secs
# Ready.
# Reading 0 ... 11618  =      0.000 ...    90.766 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1096683105_eeg.fif...
#     Range : 25164 ... 36778 =    196.594 ...   287.328 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7314658857_eeg.fif...
#     Range : 36852 ... 48465 =    287.906 ...   378.633 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8024404809_eeg.fif...
#     Range : 48597 ... 60209 =    379.664 ...   470.383 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4215369788_eeg.fif...
#     Range : 60338 ... 71950 =    471.391 ...   562.109 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/8157991642_eeg.fif...
#     Range : 12464 ... 24080 =     97.375 ...   188.125 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4762556975_eeg.fif...
#     Range : 26955 ... 38571 =    210.586 ...   301.336 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4172333126_eeg.fif...
#     Range : 42856 ... 54469 =    334.812 ...   425.539 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3455241290_eeg.fif...
#     Range : 58797 ... 70410 =    459.352 ...   550.078 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4746645675_eeg.fif...
#     Range : 25124 ... 36734 =    196.281 ...   286.984 secs
# Ready.
# Reading 0 ... 11610  =      0.000 ...    90.703 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1471582564_eeg.fif...
#     Range : 36839 ... 48451 =    287.805 ...   378.523 secs
# Ready.
# Reading 0 ... 11612  =      0.000 ...    90.719 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/6144941167_eeg.fif...
#     Range : 48523 ... 60136 =    379.086 ...   469.812 secs
# Ready.
# Reading 0 ... 11613  =      0.000 ...    90.727 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/4575067398_eeg.fif...
#     Range : 60211 ... 71827 =    470.398 ...   561.148 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1841858497_eeg.fif...
#     Range : 71896 ... 83510 =    561.688 ...   652.422 secs
# Ready.
# Reading 0 ... 11614  =      0.000 ...    90.734 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/7081425536_eeg.fif...
#     Range : 10234 ... 21850 =     79.953 ...   170.703 secs
# Ready.
# Reading 0 ... 11616  =      0.000 ...    90.750 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5527955318_eeg.fif...
#     Range : 29785 ... 41406 =    232.695 ...   323.484 secs
# Ready.
# Reading 0 ... 11621  =      0.000 ...    90.789 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/1424199427_eeg.fif...
#     Range : 46355 ... 57961 =    362.148 ...   452.820 secs
# Ready.
# Reading 0 ... 11606  =      0.000 ...    90.672 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/3966019638_eeg.fif...
#     Range : 61814 ... 73429 =    482.922 ...   573.664 secs
# Ready.
# Reading 0 ... 11615  =      0.000 ...    90.742 secs...
# Effective window size : 16.000 (s)
# Opening raw data file Dataset/eremus_dataset/pruned/train/5539348641_eeg.fif...
#     Range : 76866 ... 88151 =    600.516 ...   688.680 secs
# Ready.
# Reading 0 ... 11285  =      0.000 ...    88.164 secs...
# Effective window size : 16.000 (s)

# %%
df.head()
# Out:
#    Unnamed: 0        spotify_track_id  \
# 0           0  06s6aloy62vytl3MnT6gfl
# 1           1  0h9fnCSnbUgOEgibnQByFv
# 2           2  1iArQTuOzxvrtniGmkyy92
# 3           3  3A9vIxzGBjEfqmDK7H9exS
# 4           4  39kHMfF3dBMZMbOtoit1XF
#
#                                           song_title  label         emotion  \
# 0  Times Like These - Live at the Pantages Theatr...      0       Amusement
# 1                                      Everyday Life      2  Disappointment
# 2                                  Burden In My Hand      3           Anger
# 3                                       Pyramid Song      3            Fear
# 4                                        On The Mend      0             Joy
#
#   session_type  subject_id          id       song_author   alpha_power  \
# 0     personal          23  3784258358  ['Foo Fighters']  2.258961e-12
# 1     personal          23  2395445698      ['Coldplay']  2.269191e-12
# 2     personal          23  3049220457   ['Soundgarden']  3.825635e-12
# 3     personal          23  2667905835     ['Radiohead']  3.852573e-12
# 4     personal          23  1281311748  ['Foo Fighters']  3.885899e-12
#
#      beta_power   delta_power   theta_power      variance          mean
# 0  1.019803e-12  4.672743e-11  4.411881e-12  2.553564e-10  2.346306e-09
# 1  7.160127e-13  2.629792e-11  3.541972e-12  2.081659e-10  1.011783e-08
# 2  1.182833e-12  6.786013e-11  5.654127e-12  5.708281e-10 -1.731397e-07
# 3  1.220438e-12  5.783148e-11  6.408991e-12  3.996517e-10  1.924873e-07
# 4  1.389423e-12  8.960010e-11  7.100184e-12  4.647378e-10  6.473157e-08

# %%
# Save the DataFrame with the new features
df.to_csv('train_with_features.csv', index=False)

print("Features added to the DataFrame and saved to 'train_with_features.csv'")
# Out:
# Features added to the DataFrame and saved to 'train_with_features.csv'

# %%
import os
files = os.listdir("Dataset/eremus_dataset/pruned/train")
for file in files:
    size = os.path.getsize(f"Dataset/eremus_dataset/pruned/train/{file}")
    print(f"{file}: {size} bytes")
# Out:
# 8269497269_eeg.fif: 1493932 bytes
# 1743279177_eeg.fif: 1480092 bytes
# 8066471705_eeg.fif: 1493420 bytes
# 9187213890_eeg.fif: 1486764 bytes
# 5905614682_eeg.fif: 1493804 bytes
# 9195527806_eeg.fif: 1447292 bytes
# 6331565359_eeg.fif: 1493676 bytes
# 4824313470_eeg.fif: 1493804 bytes
# 1671587129_eeg.fif: 1493420 bytes
# 8026221597_eeg.fif: 1503932 bytes
# 4060619220_eeg.fif: 1493548 bytes
# 7933831782_eeg.fif: 1493676 bytes
# 9903556545_eeg.fif: 1493804 bytes
# 2395445698_eeg.fif: 1317372 bytes
# 3558627660_eeg.fif: 1493676 bytes
# 3784258358_eeg.fif: 1317372 bytes
# 7418038546_eeg.fif: 1444348 bytes
# 3455241290_eeg.fif: 1493420 bytes
# 5455527567_eeg.fif: 1493548 bytes
# 4274886008_eeg.fif: 1423084 bytes
# 6023281672_eeg.fif: 1493548 bytes
# 1415214270_eeg.fif: 1494188 bytes
# 5898249712_eeg.fif: 1493804 bytes
# 2644432196_eeg.fif: 1493804 bytes
# 3359788067_eeg.fif: 1493804 bytes
# 7962692464_eeg.fif: 1494572 bytes
# 7079957449_eeg.fif: 1520204 bytes
# 7833179198_eeg.fif: 1493548 bytes
# 5568667703_eeg.fif: 1493548 bytes
